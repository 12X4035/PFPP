# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-b478a6fd18e5> in <module>()
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
from Forward import forward
from Backward import backward

# %% [markdown]
# ### theta

# %% [markdown]
# #### 初期値1

# %%
from Backward import backward

theta_arr = []

for i in range(11, 51):
    theta_arr.append(0.1*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: sum(forward(12, x, 1.2, 0.8, 0.4, 1)), theta_arr))]

df_min_fw = pd.DataFrame(last_u1_mean_over1).T
df_min_fw.columns = ["theta", "min"]
"""
theta_arr = []

for i in range(11, 51):
    theta_arr.append(0.1*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(forward(12, x, 1.2, 0.8, 0.4, 1)), theta_arr))]

df_max_fw = pd.DataFrame(last_u1_mean_over1).T
df_max_fw.columns = ["theta", "max"]
"""
fw_min_x = df_min_fw["theta"]
fw_min_y = df_min_fw["min"]
"""
fw_max_x = df_max_fw["theta"]
fw_max_y = df_max_fw["max"]
"""
theta_arr = []

for i in range(11, 51):
    theta_arr.append(0.1*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: sum(backward(11, x, 1.2, 0.8, 0.4, 1)), theta_arr))]

df_min_bk = pd.DataFrame(last_u1_mean_over1).T
df_min_bk.columns = ["theta", "min"]
"""
theta_arr = []

for i in range(11, 51):
    theta_arr.append(0.1*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(backward(11, x, 1.2, 0.8, 0.4, 1)), theta_arr))]

df_max_bk = pd.DataFrame(last_u1_mean_over1).T
df_max_bk.columns = ["theta", "max"]
"""
bk_min_x = df_min_bk["theta"]
bk_min_y = df_min_bk["min"]
"""
bk_max_x = df_max_bk["theta"]
bk_max_y = df_max_bk["max"]
"""
#fig, axs = plt.subplots(2, 1, figsize=(10, 10))
#axs[0].(fw_x, fw_y)
#axs[1].scatter(bk_x, bk_y)
plt.figure(figsize=(20,10))
plt.plot(fw_min_x, fw_min_y, label = "forward_min", alpha=0.5)
#plt.plot(fw_max_x, fw_max_y, label = "forward_max", alpha=0.5)
plt.plot(bk_min_x, bk_min_y, label = "backward_min", alpha=0.5)
#plt.plot(bk_max_x, bk_max_y, label = "backward_max", alpha=0.5)
#axs[1, 0].scatter(data[0], data[1])
#axs[0, 1].plot(data[0], data[1])
#axs[1, 1].hist2d(data[0], data[1])

#plt.scatter(x, y, linewidth=0.1)
plt.title("Forward")
plt.xlabel("theta")
plt.ylabel("last_u1")
plt.legend()
plt.show()

# %% [markdown]
# #### 初期値10

# %%
from Backward import backward

theta_arr = []

for i in range(11, 51):
    theta_arr.append(0.1*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: min(forward(12, x, 1.2, 0.8, 0.4, 10)), theta_arr))]

df_min_fw = pd.DataFrame(last_u1_mean_over1).T
df_min_fw.columns = ["theta", "min"]

theta_arr = []

for i in range(11, 51):
    theta_arr.append(0.1*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(forward(12, x, 1.2, 0.8, 0.4, 10)), theta_arr))]

df_max_fw = pd.DataFrame(last_u1_mean_over1).T
df_max_fw.columns = ["theta", "max"]

fw_min_x = df_min_fw["theta"]
fw_min_y = df_min_fw["min"]

fw_max_x = df_max_fw["theta"]
fw_max_y = df_max_fw["max"]

theta_arr = []

for i in range(11, 51):
    theta_arr.append(0.1*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: min(backward(11, x, 1.2, 0.8, 0.4, 10)), theta_arr))]

df_min_bk = pd.DataFrame(last_u1_mean_over1).T
df_min_bk.columns = ["theta", "min"]

theta_arr = []

for i in range(11, 51):
    theta_arr.append(0.1*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(backward(11, x, 1.2, 0.8, 0.4, 10)), theta_arr))]

df_max_bk = pd.DataFrame(last_u1_mean_over1).T
df_max_bk.columns = ["theta", "max"]

bk_min_x = df_min_bk["theta"]
bk_min_y = df_min_bk["min"]
bk_max_x = df_max_bk["theta"]
bk_max_y = df_max_bk["max"]

#fig, axs = plt.subplots(2, 1, figsize=(10, 10))
#axs[0].(fw_x, fw_y)
#axs[1].scatter(bk_x, bk_y)
plt.figure(figsize=(20,10))
plt.plot(fw_min_x, fw_min_y, label = "forward_min", alpha=0.5)
plt.plot(fw_max_x, fw_max_y, label = "forward_max", alpha=0.5)
plt.plot(bk_min_x, bk_min_y, label = "backward_min", alpha=0.5)
plt.plot(bk_max_x, bk_max_y, label = "backward_max", alpha=0.5)
#axs[1, 0].scatter(data[0], data[1])
#axs[0, 1].plot(data[0], data[1])
#axs[1, 1].hist2d(data[0], data[1])

#plt.scatter(x, y, linewidth=0.1)
plt.title("Forward")
plt.xlabel("theta")
plt.ylabel("last_u1")
plt.legend()
plt.show()

# %% [markdown]
# #### 初期値100

# %%
from Backward import backward

theta_arr = []

for i in range(11, 51):
    theta_arr.append(0.1*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: min(forward(12, x, 1.2, 0.8, 0.4, 100)), theta_arr))]

df_min_fw = pd.DataFrame(last_u1_mean_over1).T
df_min_fw.columns = ["theta", "min"]

theta_arr = []

for i in range(11, 51):
    theta_arr.append(0.1*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(forward(12, x, 1.2, 0.8, 0.4, 100)), theta_arr))]

df_max_fw = pd.DataFrame(last_u1_mean_over1).T
df_max_fw.columns = ["theta", "max"]

fw_min_x = df_min_fw["theta"]
fw_min_y = df_min_fw["min"]

fw_max_x = df_max_fw["theta"]
fw_max_y = df_max_fw["max"]

theta_arr = []

for i in range(11, 51):
    theta_arr.append(0.1*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: min(backward(11, x, 1.2, 0.8, 0.4, 100)), theta_arr))]

df_min_bk = pd.DataFrame(last_u1_mean_over1).T
df_min_bk.columns = ["theta", "min"]

theta_arr = []

for i in range(11, 51):
    theta_arr.append(0.1*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(backward(11, x, 1.2, 0.8, 0.4, 100)), theta_arr))]

df_max_bk = pd.DataFrame(last_u1_mean_over1).T
df_max_bk.columns = ["theta", "max"]

bk_min_x = df_min_bk["theta"]
bk_min_y = df_min_bk["min"]
bk_max_x = df_max_bk["theta"]
bk_max_y = df_max_bk["max"]

#fig, axs = plt.subplots(2, 1, figsize=(10, 10))
#axs[0].(fw_x, fw_y)
#axs[1].scatter(bk_x, bk_y)
plt.figure(figsize=(20,10))
plt.plot(fw_min_x, fw_min_y, label = "forward_min", alpha=0.5)
plt.plot(fw_max_x, fw_max_y, label = "forward_max", alpha=0.5)
plt.plot(bk_min_x, bk_min_y, label = "backward_min", alpha=0.5)
plt.plot(bk_max_x, bk_max_y, label = "backward_max", alpha=0.5)
#axs[1, 0].scatter(data[0], data[1])
#axs[0, 1].plot(data[0], data[1])
#axs[1, 1].hist2d(data[0], data[1])

#plt.scatter(x, y, linewidth=0.1)
plt.title("Forward")
plt.xlabel("theta")
plt.ylabel("last_u1")
plt.legend()
plt.show()

# %%
import numpy as np
from sympy import *
from ipywidgets import interact
from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure, output_file

output_notebook() # 描画をjupyter notebookに出力

## 1.データの定義
"""
data_x_array = np.arange(0, 1, 0.01)
data_mu_array = np.arange(0, 1, 0.01)

def my_beta(data_a, data_b, data_mu):
    '''
    ベータ分布の確率密度関数
    a, bを設定した上で任意のmuを入れると、muがその値である確率を返す
    data_a: a > 0
    data_b: b > 0
    data_mu: 0 <= mu <= 1
    '''
    # sympyでは、変数に使うアルファベットをあらかじめ定義する
    # ここで使用したアルファベットを他の変数として使ってはならない
    a, b, t, x, mu = symbols('a b t x mu')

    # 関数の定義
    Gamma = Integral(t**(x - 1) * exp(-t), (t, 0, oo)) # ガンマ関数、この段階では積分を定義するだけで計算は行わない
    C = Gamma.subs(x, a + b) / (Gamma.subs(x, a) * Gamma.subs(x, b)) # ベータ分布の正規化項
    Beta = C * mu**(a - 1) * (1 - mu)**(b - 1) # ベータ分布の確率密度関数

    # a, bが与えられたときのmuの確率を計算
    prob = Beta.subs([(a, data_a), (b, data_b), (mu, data_mu)]).doit() # doit()は積分を計算するコマンド
    return np.float(prob)

data_prob_array = np.array([my_beta(1, 1, data_mu) for data_mu in data_mu_array]) # デフォルトではa=1, b=1の分布を描画する
# beta(a, b, mu)はsympy.core.numbers.NUMBERを返すので、floatに変換する必要がある
"""
def forward(N, theta, u, d, p, default_x):

    q = (1-d)/(u-d)
    a = ((1-p)/p)*(q/(1-q))
    b = (1-q)/q
    c = (1-p)/(1-q)

    
    stock = []
    tmp = []
    for i in range(N+1):
        stock.append([])
        tmp.append(i)
        for j in range(0,N+1):
            stock[i].append([])
    for i in range(N+1):
        for j in range(N+1):
            stock[i][0] = i
            stock[i][1] = tmp[0:i+1]
            stock[i][2] = tmp[i::-1]
            stock[i][3] = tmp[0:i+1]
            stock[i][4] = theta
            stock[i][5] = p
            stock[i][6] = list(map(lambda x: 0 if x==0 else u**x, tmp[0:i+1]))
            stock[i][7] = list(map(lambda x: 0 if x==0 else d**x, tmp[i::-1]))
            #price
            stock[i][8] = list(map(lambda x, y: default_x if x==0 and y==0 else (default_x*x)+(default_x*y) if x==0 or y==0 else (default_x*x)*(default_x*y), stock[i][6], stock[i][7]))
            #U_0
            stock[i][9] = list(map(lambda x: ((1-(1/theta))**(-1))*(x**(1-(1/theta))), stock[i][8]))
            #I_0
            #stock[i][10] = list(map(lambda x: (x**(-1/theta))**(-1), stock[i][8]))
            #I_1
            #stock[i][11] = list(map(lambda x: (1+b)/((c**theta)*((a**(-theta))+b)*x, stock[i][10]))
            #U_1
            stock[i][10] = list(map(lambda x: (((1+b)/((c**(theta))*((a**(-theta))+b)))**(1/theta))*x, stock[i][9]))
            #pi
            stock[i][11] = list(map(lambda x: ((((1+b)/((c**theta)*((a**(-theta))+b)))*((p/q)**theta)-1)/(u-1))*x, stock[i][8]))
            #Exp[U_1]
            stock[i][12] = list(map(lambda  l, m, n : (p**l)*((1-p)**m)*n if (l!=0 and m!=0) \
                                 else (p**l)*n if m==0 \
                                 else ((1-p)**m)*n if l==0 \
                                 else nan \
                                 , stock[i][2], stock[i][3], stock[i][10]))
            
    df = pd.DataFrame(stock)
    df = df.set_index(0)
    df.columns = ["node_num", "up_times", "down_times", "theta", "prob", "up_r", "down_r", "price", "U_0", "U_1", "alpha", "Exp_U1"]
    """
    x = np.linspace(0, 2*np.pi, 10)
    y = np.sin(x)
    plot = figure(title="simple line example", plot_height=300, plot_width=600, y_range=(-20,20))
    
    r = plot.circle(x, y, color="#2222aa")
    r.data_source.data['x'] = df.index
    r.data_source.data['y'] = df["U_1"]
    push_notebook()
    """
    last_u1_mean = list(map(lambda x: np.mean(x), df["Exp_U1"]))[10]
    
    return df["Exp_U1"][10]

def mk_arr_max (u, d, p, default_x):
    theta_arr = []
    for i in range(11, 51):
        theta_arr.append(0.1*i)
        last_u1_exp_max = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(forward(12, x, u, d, p, default_x)), theta_arr))]
    
    return last_u1_exp_max

def mk_arr_min (u, d, p, default_x):
    theta_arr = []
    for i in range(11, 51):
        theta_arr.append(0.1*i)
        last_u1_exp_min = [list(map(lambda x: x, theta_arr)), list(map(lambda x: min(forward(12, x, u, d, p, default_x)), theta_arr))]
    
    return last_u1_exp_min

default_arr = mk_arr_max(1.1, 0.9, 0.1, 1)

p = figure(title = "forward",
          plot_height = 400,
          plot_width = 800,
          y_range = (0, 5))

## 4.rendererを追加
r = p.circle(default_arr[0], default_arr[1])

## 5.interactorを定義
def update(u=1.1, d=0.9, p=0.1, default_x=1):
    r.data_source.data['y'] =  mk_arr_max(u, d, p, default_x)[1]
    push_notebook()

## 6.描画
show(p, notebook_handle=True) # notebook_handleをTrueにすると後から図を制御出来る

## 7.interactorの実行
interact(update, u = (1.1, 1.9, 0.1), d = (0.1, 0.9, 0.1), p = (0.1, 0.9, 0.1), default_x = (1, 10000, 100))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="73db0742-66d3-40ae-b9cf-f32cb749679b">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="b78c5314-3a2d-4920-ae22-41b3c4651e48"></div>
# interactive(children=(FloatSlider(value=1.1, description='u', max=1.9, min=1.1), FloatSlider(value=0.9, descri…
# <function __main__.update>

# %% [markdown]
# ### 初期値

# %% [markdown]
# #### theta = 1.2

# %%
from Backward import backward

theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: sum(forward(12, 1.2, 1.2, 0.8, 0.4, x)), theta_arr))]

df_min_fw = pd.DataFrame(last_u1_mean_over1).T
df_min_fw.columns = ["theta", "min"]
"""
theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(forward(12, 1.2, 1.2, 0.8, 0.4, x)), theta_arr))]

df_max_fw = pd.DataFrame(last_u1_mean_over1).T
df_max_fw.columns = ["theta", "max"]
"""
fw_min_x = df_min_fw["theta"]
fw_min_y = df_min_fw["min"]

#fw_max_x = df_max_fw["theta"]
#fw_max_y = df_max_fw["max"]

theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: sum(backward(11, 1.2, 1.2, 0.8, 0.4, x)), theta_arr))]

df_min_bk = pd.DataFrame(last_u1_mean_over1).T
df_min_bk.columns = ["theta", "min"]
"""
theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(backward(11, 1.2, 1.2, 0.8, 0.4, x)), theta_arr))]

df_max_bk = pd.DataFrame(last_u1_mean_over1).T
df_max_bk.columns = ["theta", "max"]
"""
bk_min_x = df_min_bk["theta"]
bk_min_y = df_min_bk["min"]

#bk_max_x = df_max_bk["theta"]
#bk_max_y = df_max_bk["max"]

#fig, axs = plt.subplots(2, 1, figsize=(10, 10))
#axs[0].(fw_x, fw_y)
#axs[1].scatter(bk_x, bk_y)
plt.figure(figsize=(20,10))
plt.plot(fw_min_x, fw_min_y, label = "forward", alpha=0.5)
#plt.plot(fw_max_x, fw_max_y, label = "forward_max", alpha=0.5)
plt.plot(bk_min_x, bk_min_y, label = "backward", alpha=0.5)
#plt.plot(bk_max_x, bk_max_y, label = "backward_max", alpha=0.5)
#axs[1, 0].scatter(data[0], data[1])
#axs[0, 1].plot(data[0], data[1])
#axs[1, 1].hist2d(data[0], data[1])

#plt.scatter(x, y, linewidth=0.1)
plt.title("theta=1.2")
plt.xlabel("default_val")
plt.ylabel("last_u1_exp")
plt.legend()
plt.show()

# %%
from Backward import backward

theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: sum(forward(12, 0.2, 1.2, 0.8, 0.4, x)), theta_arr))]

df_min_fw = pd.DataFrame(last_u1_mean_over1).T
df_min_fw.columns = ["theta", "min"]
"""
theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(forward(12, 1.2, 1.2, 0.8, 0.4, x)), theta_arr))]

df_max_fw = pd.DataFrame(last_u1_mean_over1).T
df_max_fw.columns = ["theta", "max"]
"""
fw_min_x = df_min_fw["theta"]
fw_min_y = df_min_fw["min"]

#fw_max_x = df_max_fw["theta"]
#fw_max_y = df_max_fw["max"]

theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: sum(backward(11, 0.2, 1.2, 0.8, 0.4, x)), theta_arr))]

df_min_bk = pd.DataFrame(last_u1_mean_over1).T
df_min_bk.columns = ["theta", "min"]
"""
theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(backward(11, 1.2, 1.2, 0.8, 0.4, x)), theta_arr))]

df_max_bk = pd.DataFrame(last_u1_mean_over1).T
df_max_bk.columns = ["theta", "max"]
"""
bk_min_x = df_min_bk["theta"]
bk_min_y = df_min_bk["min"]

#bk_max_x = df_max_bk["theta"]
#bk_max_y = df_max_bk["max"]

#fig, axs = plt.subplots(2, 1, figsize=(10, 10))
#axs[0].(fw_x, fw_y)
#axs[1].scatter(bk_x, bk_y)
plt.figure(figsize=(20,10))
plt.plot(fw_min_x, fw_min_y, label = "forward_min", alpha=0.5)
#plt.plot(fw_max_x, fw_max_y, label = "forward_max", alpha=0.5)
plt.plot(bk_min_x, bk_min_y, label = "backward_min", alpha=0.5)
#plt.plot(bk_max_x, bk_max_y, label = "backward_max", alpha=0.5)
#axs[1, 0].scatter(data[0], data[1])
#axs[0, 1].plot(data[0], data[1])
#axs[1, 1].hist2d(data[0], data[1])

#plt.scatter(x, y, linewidth=0.1)
plt.title("Forward")
plt.xlabel("default_val")
plt.ylabel("last_u1")
plt.legend()
plt.show()

# %%
tmp = pd.DataFrame([fw_min_y, bk_min_y]).T
tmp.columns = ["forward", "backward"]
tmp["chk"] = list(map(lambda x, y: 1 if x<y else 0, tmp["forward"], tmp["backward"]))
tmp
# Out:
#        forward    backward  chk
# 0    28.718777   28.143329    0
# 1    36.168762   35.444037    0
# 2    41.393962   40.564537    0
# 3    45.553365   44.640597    0
# 4    49.065601   48.082458    0
# 5    52.135555   51.090898    0
# 6    54.880655   53.780993    0
# 7    57.375212   56.225566    0
# 8    59.669582   58.473963    0
# 9    61.799654   60.561354    0
# 10   63.792013   62.513791    0
# 11   65.666964   64.351173    0
# 12   67.440409   66.089083    0
# 13   69.125060   67.739978    0
# 14   70.731260   69.313994    0
# 15   72.267548   70.819500    0
# 16   73.741069   72.263495    0
# 17   75.157864   73.651901    0
# 18   76.523095   74.989777    0
# 19   77.841213   76.281483    0
# 20   79.116082   77.530807    0
# 21   80.351084   78.741063    0
# 22   81.549196   79.915168    0
# 23   82.713055   81.055706    0
# 24   83.845009   82.164979    0
# 25   84.947158   83.245044    0
# 26   86.021390   84.297751    0
# 27   87.069407   85.324769    0
# 28   88.092753   86.327609    0
# 29   89.092830   87.307647    0
# ..         ...         ...  ...
# 70  118.695100  116.316767    0
# 71  119.249252  116.859815    0
# 72  119.798294  117.397856    0
# 73  120.342344  117.931005    0
# 74  120.881514  118.459371    0
# 75  121.415911  118.983060    0
# 76  121.945639  119.502174    0
# 77  122.470800  120.016812    0
# 78  122.991490  120.527069    0
# 79  123.507803  121.033037    0
# 80  124.019831  121.534805    0
# 81  124.527661  122.032459    0
# 82  125.031377  122.526082    0
# 83  125.531063  123.015755    0
# 84  126.026798  123.501557    0
# 85  126.518659  123.983562    0
# 86  127.006720  124.461845    0
# 87  127.491056  124.936475    0
# 88  127.971735  125.407523    0
# 89  128.448826  125.875054    0
# 90  128.922395  126.339134    0
# 91  129.392506  126.799826    0
# 92  129.859223  127.257191    0
# 93  130.322605  127.711288    0
# 94  130.782711  128.162175    0
# 95  131.239599  128.609908    0
# 96  131.693325  129.054542    0
# 97  132.143942  129.496130    0
# 98  132.591503  129.934724    0
# 99  133.036060  130.370373    0
#
# [100 rows x 3 columns]

# %% [markdown]
# #### theta = 2

# %%
from Backward import backward

theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: sum(forward(12, 2, 1.2, 0.8, 0.4, x)), theta_arr))]

df_min_fw = pd.DataFrame(last_u1_mean_over1).T
df_min_fw.columns = ["theta", "min"]
"""
theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(forward(12, 1.2, 1.2, 0.8, 0.4, x)), theta_arr))]

df_max_fw = pd.DataFrame(last_u1_mean_over1).T
df_max_fw.columns = ["theta", "max"]
"""
fw_min_x = df_min_fw["theta"]
fw_min_y = df_min_fw["min"]

#fw_max_x = df_max_fw["theta"]
#fw_max_y = df_max_fw["max"]

theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: sum(backward(11, 2, 1.2, 0.8, 0.4, x)), theta_arr))]

df_min_bk = pd.DataFrame(last_u1_mean_over1).T
df_min_bk.columns = ["theta", "min"]
"""
theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(backward(11, 1.2, 1.2, 0.8, 0.4, x)), theta_arr))]

df_max_bk = pd.DataFrame(last_u1_mean_over1).T
df_max_bk.columns = ["theta", "max"]
"""
bk_min_x = df_min_bk["theta"]
bk_min_y = df_min_bk["min"]

#bk_max_x = df_max_bk["theta"]
#bk_max_y = df_max_bk["max"]

#fig, axs = plt.subplots(2, 1, figsize=(10, 10))
#axs[0].(fw_x, fw_y)
#axs[1].scatter(bk_x, bk_y)
plt.figure(figsize=(20,10))
plt.plot(fw_min_x, fw_min_y, label = "forward_min", alpha=0.5)
#plt.plot(fw_max_x, fw_max_y, label = "forward_max", alpha=0.5)
plt.plot(bk_min_x, bk_min_y, label = "backward_min", alpha=0.5)
#plt.plot(bk_max_x, bk_max_y, label = "backward_max", alpha=0.5)
#axs[1, 0].scatter(data[0], data[1])
#axs[0, 1].plot(data[0], data[1])
#axs[1, 1].hist2d(data[0], data[1])

#plt.scatter(x, y, linewidth=0.1)
plt.title("Forward")
plt.xlabel("default_val")
plt.ylabel("last_u1")
plt.legend()
plt.show()

# %%
tmp = pd.DataFrame([fw_min_y, bk_min_y]).T
tmp.columns = ["forward", "backward"]
tmp["chk"] = list(map(lambda x, y: 1 if x<y else 0, tmp["forward"], tmp["backward"]))
tmp
# Out:
#          forward      backward  chk
# 0     225.024146    219.531989    0
# 1     449.875046    438.894961    0
# 2     674.697443    658.230126    0
# 3     899.505086    877.550896    0
# 4    1124.303300   1096.862468    0
# 5    1349.094817   1316.167505    0
# 6    1573.881258   1535.467592    0
# 7    1798.663681   1754.763758    0
# 8    2023.442821   1974.056721    0
# 9    2248.219212   2193.347002    0
# 10   2472.993257   2412.634994    0
# 11   2697.765270   2631.921005    0
# 12   2922.535501   2851.205276    0
# 13   3147.304151   3070.488006    0
# 14   3372.071388   3289.769356    0
# 15   3596.837350   3509.049463    0
# 16   3821.602156   3728.328442    0
# 17   4046.365905   3947.606390    0
# 18   4271.128686   4166.883393    0
# 19   4495.890573   4386.159524    0
# 20   4720.651632   4605.434849    0
# 21   4945.411923   4824.709423    0
# 22   5170.171497   5043.983297    0
# 23   5394.930400   5263.256517    0
# 24   5619.688674   5482.529124    0
# 25   5844.446356   5701.801153    0
# 26   6069.203480   5921.072637    0
# 27   6293.960077   6140.343608    0
# 28   6518.716175   6359.614091    0
# 29   6743.471799   6578.884112    0
# ..           ...           ...  ...
# 70  15958.208226  15568.716781    0
# 71  16182.954111  15787.977301    0
# 72  16407.699875  16007.237703    0
# 73  16632.445521  16226.497989    0
# 74  16857.191051  16445.758162    0
# 75  17081.936466  16665.018224    0
# 76  17306.681770  16884.278178    0
# 77  17531.426965  17103.538024    0
# 78  17756.172052  17322.797766    0
# 79  17980.917035  17542.057405    0
# 80  18205.661913  17761.316943    0
# 81  18430.406691  17980.576382    0
# 82  18655.151368  18199.835724    0
# 83  18879.895948  18419.094971    0
# 84  19104.640432  18638.354124    0
# 85  19329.384822  18857.613184    0
# 86  19554.129119  19076.872155    0
# 87  19778.873324  19296.131036    0
# 88  20003.617440  19515.389831    0
# 89  20228.361469  19734.648539    0
# 90  20453.105410  19953.907163    0
# 91  20677.849266  20173.165703    0
# 92  20902.593039  20392.424162    0
# 93  21127.336729  20611.682541    0
# 94  21352.080338  20830.940840    0
# 95  21576.823867  21050.199061    0
# 96  21801.567318  21269.457206    0
# 97  22026.310691  21488.715275    0
# 98  22251.053988  21707.973270    0
# 99  22475.797209  21927.231192    0
#
# [100 rows x 3 columns]

# %%
from Backward import backward

theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: sum(forward(12, 2.8, 1.2, 0.8, 0.4, x)), theta_arr))]

df_min_fw = pd.DataFrame(last_u1_mean_over1).T
df_min_fw.columns = ["theta", "min"]
"""
theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(forward(12, 1.2, 1.2, 0.8, 0.4, x)), theta_arr))]

df_max_fw = pd.DataFrame(last_u1_mean_over1).T
df_max_fw.columns = ["theta", "max"]
"""
fw_min_x = df_min_fw["theta"]
fw_min_y = df_min_fw["min"]

#fw_max_x = df_max_fw["theta"]
#fw_max_y = df_max_fw["max"]

theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: sum(backward(11, 2.8, 1.2, 0.8, 0.4, x)), theta_arr))]

df_min_bk = pd.DataFrame(last_u1_mean_over1).T
df_min_bk.columns = ["theta", "min"]
"""
theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(backward(11, 1.2, 1.2, 0.8, 0.4, x)), theta_arr))]

df_max_bk = pd.DataFrame(last_u1_mean_over1).T
df_max_bk.columns = ["theta", "max"]
"""
bk_min_x = df_min_bk["theta"]
bk_min_y = df_min_bk["min"]

#bk_max_x = df_max_bk["theta"]
#bk_max_y = df_max_bk["max"]

#fig, axs = plt.subplots(2, 1, figsize=(10, 10))
#axs[0].(fw_x, fw_y)
#axs[1].scatter(bk_x, bk_y)
plt.figure(figsize=(20,10))
plt.plot(fw_min_x, fw_min_y, label = "forward_min", alpha=0.5)
#plt.plot(fw_max_x, fw_max_y, label = "forward_max", alpha=0.5)
plt.plot(bk_min_x, bk_min_y, label = "backward_min", alpha=0.5)
#plt.plot(bk_max_x, bk_max_y, label = "backward_max", alpha=0.5)
#axs[1, 0].scatter(data[0], data[1])
#axs[0, 1].plot(data[0], data[1])
#axs[1, 1].hist2d(data[0], data[1])

#plt.scatter(x, y, linewidth=0.1)
plt.title("Forward")
plt.xlabel("default_val")
plt.ylabel("last_u1")
plt.legend()
plt.show()

# %%
tmp = pd.DataFrame([fw_min_y, bk_min_y]).T
tmp.columns = ["forward", "backward"]
tmp["chk"] = list(map(lambda x, y: 1 if x<y else 0, tmp["forward"], tmp["backward"]))
tmp
# Out:
#           forward       backward  chk
# 0      680.412244     677.160496    0
# 1     1658.366344    1650.440871    0
# 2     2792.738639    2779.391905    0
# 3     4042.365959    4023.047151    0
# 4     5385.355271    5359.618203    0
# 5     6807.765373    6775.230486    0
# 6     8299.811332    8260.145832    0
# 7     9854.186198    9807.092210    0
# 8    11465.192545   11410.399421    0
# 9    13128.243804   13065.502817    0
# 10   14839.555737   14768.636246    0
# 11   16595.944457   16516.631035    0
# 12   18394.688209   18306.778439    0
# 13   20233.429342   20136.732073    0
# 14   22110.102699   22004.436649    0
# 15   24022.881989   23908.074606    0
# 16   25970.138780   25846.025292    0
# 17   27950.410551   27816.833177    0
# 18   29962.375416   29819.182692    0
# 19   32004.831838   31851.878042    0
# 20   34076.682146   33913.826802    0
# 21   36176.918997   36004.026443    0
# 22   38304.614140   38121.553151    0
# 23   40458.909010   40265.552464    0
# 24   42639.006794   42435.231376    0
# 25   44844.165673   44629.851615    0
# 26   47073.693050   46848.723892    0
# 27   49326.940564   49091.202946    0
# 28   51603.299781   51356.683249    0
# 29   53902.198432   53644.595270    0
# ..            ...            ...  ...
# 70  163163.336951  162383.565573    0
# 71  166123.850126  165329.930204    0
# 72  169096.134325  168288.009607    0
# 73  172080.074144  171257.688925    0
# 74  175075.556856  174238.855972    0
# 75  178082.472315  177231.401127    0
# 76  181100.712864  180235.217250    0
# 77  184130.173251  183250.199589    0
# 78  187170.750536  186276.245699    0
# 79  190222.344023  189313.255362    0
# 80  193284.855172  192361.130512    0
# 81  196358.187537  195419.775162    0
# 82  199442.246690  198489.095336    0
# 83  202536.940156  201568.999000    0
# 84  205642.177351  204659.396004    0
# 85  208757.869523  207760.198019    0
# 86  211883.929689  210871.318480    0
# 87  215020.272585  213992.672528    0
# 88  218166.814610  217124.176963    0
# 89  221323.473777  220265.750189    0
# 90  224490.169662  223417.312167    0
# 91  227666.823359  226578.784367    0
# 92  230853.357433  229750.089726    0
# 93  234049.695883  232931.152604    0
# 94  237255.764091  236121.898741    0
# 95  240471.488791  239322.255221    0
# 96  243696.798026  242532.150430    0
# 97  246931.621113  245751.514024    0
# 98  250175.888607  248980.276889    0
# 99  253429.532267  252218.371112    0
#
# [100 rows x 3 columns]

# %% [markdown]
# #### theta = 3

# %%
from Backward import backward

theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: sum(forward(12, 3, 1.2, 0.8, 0.4, x)), theta_arr))]

df_min_fw = pd.DataFrame(last_u1_mean_over1).T
df_min_fw.columns = ["theta", "min"]
"""
theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(forward(12, 1.2, 1.2, 0.8, 0.4, x)), theta_arr))]

df_max_fw = pd.DataFrame(last_u1_mean_over1).T
df_max_fw.columns = ["theta", "max"]
"""
fw_min_x = df_min_fw["theta"]
fw_min_y = df_min_fw["min"]

#fw_max_x = df_max_fw["theta"]
#fw_max_y = df_max_fw["max"]

theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: sum(backward(11, 3, 1.2, 0.8, 0.4, x)), theta_arr))]

df_min_bk = pd.DataFrame(last_u1_mean_over1).T
df_min_bk.columns = ["theta", "min"]
"""
theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(backward(11, 1.2, 1.2, 0.8, 0.4, x)), theta_arr))]

df_max_bk = pd.DataFrame(last_u1_mean_over1).T
df_max_bk.columns = ["theta", "max"]
"""
bk_min_x = df_min_bk["theta"]
bk_min_y = df_min_bk["min"]

#bk_max_x = df_max_bk["theta"]
#bk_max_y = df_max_bk["max"]

#fig, axs = plt.subplots(2, 1, figsize=(10, 10))
#axs[0].(fw_x, fw_y)
#axs[1].scatter(bk_x, bk_y)
plt.figure(figsize=(20,10))
plt.plot(fw_min_x, fw_min_y, label = "forward_min", alpha=0.5)
#plt.plot(fw_max_x, fw_max_y, label = "forward_max", alpha=0.5)
plt.plot(bk_min_x, bk_min_y, label = "backward_min", alpha=0.5)
#plt.plot(bk_max_x, bk_max_y, label = "backward_max", alpha=0.5)
#axs[1, 0].scatter(data[0], data[1])
#axs[0, 1].plot(data[0], data[1])
#axs[1, 1].hist2d(data[0], data[1])

#plt.scatter(x, y, linewidth=0.1)
plt.title("Forward")
plt.xlabel("default_val")
plt.ylabel("last_u1")
plt.legend()
plt.show()

# %%
tmp = pd.DataFrame([fw_min_y, bk_min_y]).T
tmp.columns = ["forward", "backward"]
tmp["chk"] = list(map(lambda x, y: 1 if x<y else 0, tmp["forward"], tmp["backward"]))
tmp
# Out:
#           forward       backward  chk
# 0      822.450206     822.953575    1
# 1     2071.852368    2073.120417    1
# 2     3557.108289    3559.285367    1
# 3     5219.800626    5222.995333    1
# 4     7028.276804    7032.578363    1
# 5     8962.119214    8967.604355    1
# 6    11006.853257   11013.589848    1
# 7    13151.580903   13159.630145    1
# 8    15387.745255   15397.163110    1
# 9    17708.415924   17719.254114    1
# 10   20107.844092   20120.150818    1
# 11   22581.169613   22594.990104    1
# 12   25124.219588   25139.596517    1
# 13   27733.364866   27750.338686    1
# 14   30405.414792   30424.024003    1
# 15   33137.538093   33157.819462    1
# 16   35927.202167   35949.190912    1
# 17   38772.125640   38795.855580    1
# 18   41670.240703   41695.744394    1
# 19   44619.662816   44646.971660    1
# 20   47618.666015   47647.810357    1
# 21   50665.662579   50696.671793    1
# 22   53759.186120   53792.088682    1
# 23   56897.877395   56932.700949    1
# 24   60080.472295   60117.243712    1
# 25   63305.791625   63344.537053    1
# 26   66572.732324   66613.477238    1
# 27   69880.259894   69923.029135    1
# 28   73227.401823   73272.219635    1
# 29   76613.241848   76660.131917    1
# ..            ...            ...  ...
# 70  241622.909131  241770.791070    1
# 71  246170.943878  246321.609378    1
# 72  250740.082779  250893.544757    1
# 73  255330.132653  255486.403907    1
# 74  259940.904681  260099.997894    1
# 75  264572.214248  264734.141990    1
# 76  269223.880800  269388.655529    1
# 77  273895.727696  274063.361764    1
# 78  278587.582079  278758.087732    1
# 79  283299.274749  283472.664128    1
# 80  288030.640036  288206.925181    1
# 81  292781.515686  292960.708538    1
# 82  297551.742752  297733.855155    1
# 83  302341.165483  302526.209186    1
# 84  307149.631226  307337.617884    1
# 85  311976.990327  312167.931503    1
# 86  316823.096038  317017.003205    1
# 87  321687.804427  321884.688971    1
# 88  326570.974294  326770.847515    1
# 89  331472.467090  331675.340200    1
# 90  336392.146833  336598.030965    1
# 91  341329.880038  341538.786241    1
# 92  346285.535644  346497.474887    1
# 93  351258.984942  351473.968116    1
# 94  356250.101508  356468.139425    1
# 95  361258.761142  361479.864540    1
# 96  366284.841803  366509.021343    1
# 97  371328.223551  371555.489823    1
# 98  376388.788489  376619.152009    1
# 99  381466.420707  381699.891922    1
#
# [100 rows x 3 columns]

# %% [markdown]
# #### theta=10

# %%
from Backward import backward

theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: sum(forward(12, 10, 1.2, 0.8, 0.4, x)), theta_arr))]

df_min_fw = pd.DataFrame(last_u1_mean_over1).T
df_min_fw.columns = ["theta", "min"]
"""
theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(forward(12, 1.2, 1.2, 0.8, 0.4, x)), theta_arr))]

df_max_fw = pd.DataFrame(last_u1_mean_over1).T
df_max_fw.columns = ["theta", "max"]
"""
fw_min_x = df_min_fw["theta"]
fw_min_y = df_min_fw["min"]

#fw_max_x = df_max_fw["theta"]
#fw_max_y = df_max_fw["max"]

theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: sum(backward(11, 10, 1.2, 0.8, 0.4, x)), theta_arr))]

df_min_bk = pd.DataFrame(last_u1_mean_over1).T
df_min_bk.columns = ["theta", "min"]
"""
theta_arr = []

for i in range(1, 101):
    theta_arr.append(100*i)
    last_u1_mean_over1 = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(backward(11, 1.2, 1.2, 0.8, 0.4, x)), theta_arr))]

df_max_bk = pd.DataFrame(last_u1_mean_over1).T
df_max_bk.columns = ["theta", "max"]
"""
bk_min_x = df_min_bk["theta"]
bk_min_y = df_min_bk["min"]

#bk_max_x = df_max_bk["theta"]
#bk_max_y = df_max_bk["max"]

#fig, axs = plt.subplots(2, 1, figsize=(10, 10))
#axs[0].(fw_x, fw_y)
#axs[1].scatter(bk_x, bk_y)
plt.figure(figsize=(20,10))
plt.plot(fw_min_x, fw_min_y, label = "forward_min", alpha=0.5)
#plt.plot(fw_max_x, fw_max_y, label = "forward_max", alpha=0.5)
plt.plot(bk_min_x, bk_min_y, label = "backward_min", alpha=0.5)
#plt.plot(bk_max_x, bk_max_y, label = "backward_max", alpha=0.5)
#axs[1, 0].scatter(data[0], data[1])
#axs[0, 1].plot(data[0], data[1])
#axs[1, 1].hist2d(data[0], data[1])

#plt.scatter(x, y, linewidth=0.1)
plt.title("Forward")
plt.xlabel("default_val")
plt.ylabel("last_u1")
plt.legend()
plt.show()

# %%
tmp = pd.DataFrame([fw_min_y, bk_min_y]).T
tmp.columns = ["forward", "backward"]
tmp["chk"] = list(map(lambda x, y: 1 if x<y else 0, tmp["forward"], tmp["backward"]))
tmp
# Out:
#          forward      backward  chk
# 0   5.400016e+03  6.037813e+03    1
# 1   1.880079e+04  2.102136e+04    1
# 2   3.900450e+04  4.361134e+04    1
# 3   6.546228e+04  7.319405e+04    1
# 4   9.781849e+04  1.093719e+05    1
# 5   1.358131e+05  1.518540e+05    1
# 6   1.792428e+05  2.004133e+05    1
# 7   2.279419e+05  2.548642e+05    1
# 8   2.817710e+05  3.150511e+05    1
# 9   3.406104e+05  3.808399e+05    1
# 10  4.043552e+05  4.521137e+05    1
# 11  4.729128e+05  5.287687e+05    1
# 12  5.462000e+05  6.107119e+05    1
# 13  6.241416e+05  6.978592e+05    1
# 14  7.066691e+05  7.901339e+05    1
# 15  7.937194e+05  8.874658e+05    1
# 16  8.852347e+05  9.897900e+05    1
# 17  9.811609e+05  1.097046e+06    1
# 18  1.081448e+06  1.209178e+06    1
# 19  1.186049e+06  1.326134e+06    1
# 20  1.294920e+06  1.447863e+06    1
# 21  1.408019e+06  1.574321e+06    1
# 22  1.525308e+06  1.705463e+06    1
# 23  1.646749e+06  1.841247e+06    1
# 24  1.772306e+06  1.981634e+06    1
# 25  1.901947e+06  2.126587e+06    1
# 26  2.035640e+06  2.276070e+06    1
# 27  2.173354e+06  2.430049e+06    1
# 28  2.315059e+06  2.588491e+06    1
# 29  2.460729e+06  2.751366e+06    1
# ..           ...           ...  ...
# 70  1.160130e+07  1.297153e+07    1
# 71  1.189707e+07  1.330223e+07    1
# 72  1.219614e+07  1.363663e+07    1
# 73  1.249852e+07  1.397472e+07    1
# 74  1.280417e+07  1.431648e+07    1
# 75  1.311311e+07  1.466190e+07    1
# 76  1.342532e+07  1.501098e+07    1
# 77  1.374078e+07  1.536371e+07    1
# 78  1.405950e+07  1.572007e+07    1
# 79  1.438146e+07  1.608006e+07    1
# 80  1.470666e+07  1.644367e+07    1
# 81  1.503509e+07  1.681089e+07    1
# 82  1.536673e+07  1.718170e+07    1
# 83  1.570159e+07  1.755611e+07    1
# 84  1.603966e+07  1.793410e+07    1
# 85  1.638091e+07  1.831567e+07    1
# 86  1.672536e+07  1.870080e+07    1
# 87  1.707299e+07  1.908949e+07    1
# 88  1.742380e+07  1.948173e+07    1
# 89  1.777777e+07  1.987751e+07    1
# 90  1.813491e+07  2.027682e+07    1
# 91  1.849519e+07  2.067967e+07    1
# 92  1.885863e+07  2.108602e+07    1
# 93  1.922520e+07  2.149589e+07    1
# 94  1.959491e+07  2.190927e+07    1
# 95  1.996774e+07  2.232613e+07    1
# 96  2.034369e+07  2.274649e+07    1
# 97  2.072276e+07  2.317033e+07    1
# 98  2.110493e+07  2.359764e+07    1
# 99  2.149021e+07  2.402842e+07    1
#
# [100 rows x 3 columns]

# %%
import numpy as np
from sympy import *
from ipywidgets import interact
from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure, output_file
from scipy.special import comb

output_notebook() # 描画をjupyter notebookに出力

## 1.データの定義
"""
data_x_array = np.arange(0, 1, 0.01)
data_mu_array = np.arange(0, 1, 0.01)

def my_beta(data_a, data_b, data_mu):
    '''
    ベータ分布の確率密度関数
    a, bを設定した上で任意のmuを入れると、muがその値である確率を返す
    data_a: a > 0
    data_b: b > 0
    data_mu: 0 <= mu <= 1
    '''
    # sympyでは、変数に使うアルファベットをあらかじめ定義する
    # ここで使用したアルファベットを他の変数として使ってはならない
    a, b, t, x, mu = symbols('a b t x mu')

    # 関数の定義
    Gamma = Integral(t**(x - 1) * exp(-t), (t, 0, oo)) # ガンマ関数、この段階では積分を定義するだけで計算は行わない
    C = Gamma.subs(x, a + b) / (Gamma.subs(x, a) * Gamma.subs(x, b)) # ベータ分布の正規化項
    Beta = C * mu**(a - 1) * (1 - mu)**(b - 1) # ベータ分布の確率密度関数

    # a, bが与えられたときのmuの確率を計算
    prob = Beta.subs([(a, data_a), (b, data_b), (mu, data_mu)]).doit() # doit()は積分を計算するコマンド
    return np.float(prob)

data_prob_array = np.array([my_beta(1, 1, data_mu) for data_mu in data_mu_array]) # デフォルトではa=1, b=1の分布を描画する
# beta(a, b, mu)はsympy.core.numbers.NUMBERを返すので、floatに変換する必要がある
"""
def forward(N, theta, u, d, p, default_x):

    q = (1-d)/(u-d)
    a = ((1-p)/p)*(q/(1-q))
    b = (1-q)/q
    c = (1-p)/(1-q)

    
    stock = []
    tmp = []
    for i in range(N+1):
        stock.append([])
        tmp.append(i)
        for j in range(0,N+1):
            stock[i].append([])
    for i in range(N+1):
        for j in range(N+1):
            stock[i][0] = i
            stock[i][1] = tmp[0:i+1]
            stock[i][2] = tmp[i::-1]
            stock[i][3] = tmp[0:i+1]
            stock[i][4] = theta
            stock[i][5] = p
            stock[i][6] = list(map(lambda x: 0 if x==0 else u**x, tmp[0:i+1]))
            stock[i][7] = list(map(lambda x: 0 if x==0 else d**x, tmp[i::-1]))
            #price
            stock[i][8] = list(map(lambda x, y: default_x if x==0 and y==0 else (default_x*x)+(default_x*y) if x==0 or y==0 else (default_x*x)*(default_x*y), stock[i][6], stock[i][7]))
            #U_0
            stock[i][9] = list(map(lambda x: ((1-(1/theta))**(-1))*(x**(1-(1/theta))), stock[i][8]))
            #I_0
            #stock[i][10] = list(map(lambda x: (x**(-1/theta))**(-1), stock[i][8]))
            #I_1
            #stock[i][11] = list(map(lambda x: (1+b)/((c**theta)*((a**(-theta))+b)*x, stock[i][10]))
            #U_1
            stock[i][10] = list(map(lambda x: (((1+b)/((c**(theta))*((a**(-theta))+b)))**(1/theta))*x, stock[i][9]))
            #pi
            stock[i][11] = list(map(lambda x: ((((1+b)/((c**theta)*((a**(-theta))+b)))*((p/q)**theta)-1)/(u-1))*x, stock[i][8]))
            #Exp[U_1]
            stock[i][12] = list(map(lambda  l, m, n : comb(i, l, exact=True)*(p**l)*((1-p)**m)*n if (l!=0 and m!=0) \
                                 else (p**l)*n if m==0 \
                                 else ((1-p)**m)*n if l==0 \
                                 else nan \
                                 , stock[i][2], stock[i][3], stock[i][10]))
            
    df = pd.DataFrame(stock)
    df = df.set_index(0)
    df.columns = ["node_num", "up_times", "down_times", "theta", "prob", "up_r", "down_r", "price", "U_0", "U_1", "alpha", "Exp_U1"]
    """
    x = np.linspace(0, 2*np.pi, 10)
    y = np.sin(x)
    plot = figure(title="simple line example", plot_height=300, plot_width=600, y_range=(-20,20))
    
    r = plot.circle(x, y, color="#2222aa")
    r.data_source.data['x'] = df.index
    r.data_source.data['y'] = df["U_1"]
    push_notebook()
    """
    last_u1_mean = list(map(lambda x: np.mean(x), df["Exp_U1"]))[10]
    
    return df["Exp_U1"][10]

def mk_arr_max (theta, u, d, p):
    theta_arr = []
    for i in range(1, 11):
        theta_arr.append(100*i)
        last_u1_exp_max = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(forward(12, theta, u, d, p, x)), theta_arr))]
    
    return last_u1_exp_max

def mk_arr_min (u, d, p, default_x):
    theta_arr = []
    for i in range(1, 100):
        theta_arr.append(10*i)
        last_u1_exp_min = [list(map(lambda x: x, theta_arr)), list(map(lambda x: min(forward(12, theta, u, d, p, x)), theta_arr))]
    
    return last_u1_exp_min

default_arr = mk_arr_max(1.1, 1.1, 0.9, 0.1)

p = figure(title = "forward",
          plot_height = 400,
          plot_width = 800)
p.xaxis.axis_label = 'default_val'
p.yaxis.axis_label = 'last_u1'


## 4.rendererを追加
r = p.circle(default_arr[0], default_arr[1])

## 5.interactorを定義
def update(theta=1, u=1.1, d=0.9, p=0.1):
    r.data_source.data['y'] =  mk_arr_max(theta, u, d, p)[1]
    push_notebook()

## 6.描画
show(p, notebook_handle=True) # notebook_handleをTrueにすると後から図を制御出来る

## 7.interactorの実行
interact(update, theta = (1.1, 10, 0.1), u = (1.1, 1.9, 0.1), d = (0.1, 0.9, 0.1), p = (0.1, 0.9, 0.1))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d0a57292-e113-4a37-9103-d267487aa019">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="01d8875b-c203-4404-8d4d-5cd0f1ccf2a4"></div>
# interactive(children=(FloatSlider(value=1.1, description='theta', max=10.0, min=1.1), FloatSlider(value=1.1, d…
# <function __main__.update>

# %%
import numpy as np
from sympy import *
from ipywidgets import interact
from bokeh.io import push_notebook, show, output_notebook
from bokeh.plotting import figure, output_file
from scipy.special import comb

output_notebook() # 描画をjupyter notebookに出力

## 1.データの定義
"""
data_x_array = np.arange(0, 1, 0.01)
data_mu_array = np.arange(0, 1, 0.01)

def my_beta(data_a, data_b, data_mu):
    '''
    ベータ分布の確率密度関数
    a, bを設定した上で任意のmuを入れると、muがその値である確率を返す
    data_a: a > 0
    data_b: b > 0
    data_mu: 0 <= mu <= 1
    '''
    # sympyでは、変数に使うアルファベットをあらかじめ定義する
    # ここで使用したアルファベットを他の変数として使ってはならない
    a, b, t, x, mu = symbols('a b t x mu')

    # 関数の定義
    Gamma = Integral(t**(x - 1) * exp(-t), (t, 0, oo)) # ガンマ関数、この段階では積分を定義するだけで計算は行わない
    C = Gamma.subs(x, a + b) / (Gamma.subs(x, a) * Gamma.subs(x, b)) # ベータ分布の正規化項
    Beta = C * mu**(a - 1) * (1 - mu)**(b - 1) # ベータ分布の確率密度関数

    # a, bが与えられたときのmuの確率を計算
    prob = Beta.subs([(a, data_a), (b, data_b), (mu, data_mu)]).doit() # doit()は積分を計算するコマンド
    return np.float(prob)

data_prob_array = np.array([my_beta(1, 1, data_mu) for data_mu in data_mu_array]) # デフォルトではa=1, b=1の分布を描画する
# beta(a, b, mu)はsympy.core.numbers.NUMBERを返すので、floatに変換する必要がある
"""
def forward(N, theta, u, d, p, default_x):

    q = (1-d)/(u-d)
    a = ((1-p)/p)*(q/(1-q))
    b = (1-q)/q
    c = (1-p)/(1-q)

    
    stock = []
    tmp = []
    for i in range(N+1):
        stock.append([])
        tmp.append(i)
        for j in range(0,N+1):
            stock[i].append([])
    for i in range(N+1):
        for j in range(N+1):
            stock[i][0] = i
            stock[i][1] = tmp[0:i+1]
            stock[i][2] = tmp[i::-1]
            stock[i][3] = tmp[0:i+1]
            stock[i][4] = theta
            stock[i][5] = p
            stock[i][6] = list(map(lambda x: 0 if x==0 else u**x, tmp[0:i+1]))
            stock[i][7] = list(map(lambda x: 0 if x==0 else d**x, tmp[i::-1]))
            #price
            stock[i][8] = list(map(lambda x, y: default_x if x==0 and y==0 else (default_x*x)+(default_x*y) if x==0 or y==0 else (default_x*x)*(default_x*y), stock[i][6], stock[i][7]))
            #U_0
            stock[i][9] = list(map(lambda x: ((1-(1/theta))**(-1))*(x**(1-(1/theta))), stock[i][8]))
            #I_0
            #stock[i][10] = list(map(lambda x: (x**(-1/theta))**(-1), stock[i][8]))
            #I_1
            #stock[i][11] = list(map(lambda x: (1+b)/((c**theta)*((a**(-theta))+b)*x, stock[i][10]))
            #U_1
            stock[i][10] = list(map(lambda x: (((1+b)/((c**(theta))*((a**(-theta))+b)))**(1/theta))*x, stock[i][9]))
            #pi
            stock[i][11] = list(map(lambda x: ((((1+b)/((c**theta)*((a**(-theta))+b)))*((p/q)**theta)-1)/(u-1))*x, stock[i][8]))
            #Exp[U_1]
            stock[i][12] = list(map(lambda  l, m, n : comb(i, l, exact=True)*(p**l)*((1-p)**m)*n if (l!=0 and m!=0) \
                                 else (p**l)*n if m==0 \
                                 else ((1-p)**m)*n if l==0 \
                                 else nan \
                                 , stock[i][2], stock[i][3], stock[i][10]))
            
    df = pd.DataFrame(stock)
    df = df.set_index(0)
    df.columns = ["node_num", "up_times", "down_times", "theta", "prob", "up_r", "down_r", "price", "U_0", "U_1", "alpha", "Exp_U1"]
    """
    x = np.linspace(0, 2*np.pi, 10)
    y = np.sin(x)
    plot = figure(title="simple line example", plot_height=300, plot_width=600, y_range=(-20,20))
    
    r = plot.circle(x, y, color="#2222aa")
    r.data_source.data['x'] = df.index
    r.data_source.data['y'] = df["U_1"]
    push_notebook()
    """
    last_u1_mean = list(map(lambda x: np.mean(x), df["Exp_U1"]))[10]
    
    return df["Exp_U1"][10]

def mk_arr_max (theta, u, d, p):
    theta_arr = []
    for i in range(1, 11):
        theta_arr.append(100*i)
        last_u1_exp_max = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(forward(12, theta, u, d, p, x)), theta_arr))]
    
    return last_u1_exp_max
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="fc80fa0c-a650-48c3-9231-80181a0880af">Loading BokehJS ...</span>
#     </div>

# %%
print(forward(12, 3, 1.2, 0.8, 0.4, 100))
mk_arr_max (3, 1.2, 0.8, 0.4)
# Out:
# [0.0007371429982115616, 0.31215515388950843, 2.7610130245968554, 14.471802247021763, 49.77899219681754, 117.41207887098116, 192.31668454831257, 216.00526971119027, 159.21392391544876, 69.54308682327371, 0.634462652182274]
# [[100, 200, 300, 400, 500, 600, 700, 800, 900, 1000],
#  [216.00526971119027,
#   544.2991723946963,
#   934.6005222753002,
#   1371.5479694808726,
#   1846.8190778077394,
#   2355.0457425147865,
#   2892.4225125158737,
#   3456.0843153790456,
#   4043.781604981894,
#   4653.692462954819]]

# %%
theta_arr = []
for i in range(1, 11):
    theta_arr.append(100*i)
    last_u1_exp_min = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(forward(12, 3, 1.2, 0.8, 0.4, 100))))]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-a1d526c6a85c> in <module>()
#       2 for i in range(1, 11):
#       3     theta_arr.append(100*i)
# ----> 4     last_u1_exp_min = [list(map(lambda x: x, theta_arr)), list(map(lambda x: max(forward(12, 3, 1.2, 0.8, 0.4, 100))))]
#
# TypeError: map() must have at least two arguments.

# %%
from scipy.special import comb
comb(5, 2, exact=True)
# Out:
# 10

# %%
def fn(theta, u, d, p):
    
    q = (1-d)/(u-d)
    a = ((1-p)/p)*(q/(1-q))
    b = (1-q)/q
    c = (1-p)/(1-q)

    delta = ((1+b)/((c**(theta))*((a**(-theta))+b)))**(1/theta)
    
    return delta

theta_arr=[]
for i in range(10, 100):
    theta_arr.append(i*0.1)
    last_u1_exp_min = list(map(lambda x: fn(x, 1.2, 0.8, 0.4)**(1/x), theta_arr))
#print(q, a, b, c)
#print(delta)

# %%
plt.figure(figsize=(20,10))
plt.plot(theta_arr, last_u1_exp_min, label = "forward_min")
plt.title("Forward")
plt.xlabel("theta")
plt.ylabel("delta")
plt.legend()
plt.show()

# %%
(fn(theta, 1.2, 0.8, 0.4)**(1/theta))*(1-(1/theta))**(-1)
# Out:
# 1.3154213309147376

# %%
u=1.2
d=0.8
p=0.4
q = (1-d)/(u-d)
a = ((1-p)/p)*(q/(1-q))
b = (1-q)/q
c = (1-p)/(1-q)
print(q)
print(a)
print(b)
print(c)
# Out:
# 0.5
# 1.4999999999999998
# 1.0
# 1.2
